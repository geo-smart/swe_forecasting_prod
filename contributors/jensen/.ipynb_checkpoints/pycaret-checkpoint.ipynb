# %%
# %pip install pycaret scikit-learn==1.2.2 yellowbrick schemdraw lightgbm scikit-plot --no-deps
# %pip install --upgrade category_encoders
# Out:
# Requirement already satisfied: pycaret in /home/ubuntu/anaconda3/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: scikit-learn==1.2.2 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: yellowbrick in /home/ubuntu/anaconda3/lib/python3.11/site-packages (1.5)
# Requirement already satisfied: schemdraw in /home/ubuntu/anaconda3/lib/python3.11/site-packages (0.17)
# Requirement already satisfied: lightgbm in /home/ubuntu/anaconda3/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: scikit-plot in /home/ubuntu/anaconda3/lib/python3.11/site-packages (0.3.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: category_encoders in /home/ubuntu/anaconda3/lib/python3.11/site-packages (2.6.2)
# Requirement already satisfied: numpy>=1.14.0 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (1.11.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /home/ubuntu/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.9.0->category_encoders) (23.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pycaret
pycaret.__version__
# Out:
# '3.0.4'

# %% [markdown]
# ## Read Our New Merged CSV
#
# This code is an initial step in a data analysis or manipulation process. It loads data from a CSV file into a Pandas DataFrame and provides an overview of the column names, which is essential for understanding and working with the dataset effectively.
#
# The loaded data can be further processed, analyzed, and visualized using various Pandas and data analysis techniques in Python.

# %%
import pandas as pd
# Read in data and display first 5 rows
features = pd.read_csv('/home/ubuntu/gridmet_test_run/all_merged_training_water_year_winter_month_only_with_no_snow.csv')
print(features.columns)
features.drop(["date", "Unnamed: 0.1", "Unnamed: 0"], axis=1, inplace=True)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'date', 'lat', 'lon', 'swe_value',
#        'station_elevation', 'elevation', 'aspect', 'curvature', 'slope',
#        'eastness', 'northness', 'etr', 'pr', 'rmax', 'rmin', 'tmmn', 'tmmx',
#        'vpd', 'vs', 'lc_code', 'fSCA', 'cumulative_etr', 'cumulative_rmax',
#        'cumulative_rmin', 'cumulative_tmmn', 'cumulative_tmmx',
#        'cumulative_vpd', 'cumulative_vs', 'cumulative_pr'],
#       dtype='object')

# %% [markdown]
# ### check the data frame shape

# %%
features.shape
# Out:
# (5480, 30)

# %% [markdown]
# ## Split the Data into Training and Testing
#
# This is a typical step for the machine learning workflow, as it divides the dataset into training and testing subsets. The training set is used to train machine learning models, while the testing set is reserved for evaluating model performance. Monitoring the dimensions of these sets helps ensure that you have an appropriate amount of data for both training and evaluation, which is essential for effective model development and validation.

# %%
train_df = features[:6000]
test_df = features[6000:]
print('Data for Modeling: ' + str(train_df.shape))
print('Unseen Data For Predictions: ' + str(test_df.shape))
# Out:
# Data for Modeling: (5480, 30)
# Unseen Data For Predictions: (0, 30)

# %%
from pycaret.regression import *
exp_reg101 = setup(data = train_df, 
                   target = 'swe_value',
                   # imputation_type='iterative', 
                   fold_shuffle=True, 
                   session_id=123)
# Out:
# <style type="text/css">
# #T_00786_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_00786">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00786_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_00786_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00786_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_00786_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00786_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_00786_row1_col1" class="data row1 col1" >swe_value</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00786_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_00786_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00786_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_00786_row3_col1" class="data row3 col1" >(5480, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00786_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_00786_row4_col1" class="data row4 col1" >(5480, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00786_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_00786_row5_col1" class="data row5 col1" >(3835, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00786_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_00786_row6_col1" class="data row6 col1" >(1645, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00786_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_00786_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00786_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_00786_row8_col1" class="data row8 col1" >28.5%</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00786_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_00786_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_00786_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_00786_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_00786_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_00786_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_00786_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_00786_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_00786_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_00786_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_00786_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_00786_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_00786_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_00786_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_00786_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_00786_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_00786_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_00786_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_00786_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_00786_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_00786_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_00786_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_00786_row19_col1" class="data row19 col1" >1e35</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Model Comparison
#
# The compare_models function trains and evaluates the performance of all the estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function.

# %%
best = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_591ea th {
#   text-align: left;
# }
# #T_591ea_row0_col0, #T_591ea_row1_col0, #T_591ea_row1_col1, #T_591ea_row1_col2, #T_591ea_row1_col3, #T_591ea_row1_col4, #T_591ea_row1_col5, #T_591ea_row1_col6, #T_591ea_row2_col0, #T_591ea_row2_col1, #T_591ea_row2_col2, #T_591ea_row2_col3, #T_591ea_row2_col4, #T_591ea_row2_col5, #T_591ea_row2_col6, #T_591ea_row3_col0, #T_591ea_row3_col1, #T_591ea_row3_col2, #T_591ea_row3_col3, #T_591ea_row3_col4, #T_591ea_row3_col5, #T_591ea_row3_col6, #T_591ea_row4_col0, #T_591ea_row4_col1, #T_591ea_row4_col2, #T_591ea_row4_col3, #T_591ea_row4_col4, #T_591ea_row4_col5, #T_591ea_row4_col6, #T_591ea_row5_col0, #T_591ea_row5_col1, #T_591ea_row5_col2, #T_591ea_row5_col3, #T_591ea_row5_col4, #T_591ea_row5_col5, #T_591ea_row5_col6, #T_591ea_row6_col0, #T_591ea_row6_col1, #T_591ea_row6_col2, #T_591ea
>0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_591ea_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_591ea_row1_col1" class="data row1 col1" >0.5164</td>
#       <td id="T_591ea_row1_col2" class="data row1 col2" >2.0493</td>
#       <td id="T_591ea_row1_col3" class="data row1 col3" >1.4201</td>
#       <td id="T_591ea_row1_col4" class="data row1 col4" >0.9973</td>
#       <td id="T_591ea_row1_col5" class="data row1 col5" >0.1564</td>
#       <td id="T_591ea_row1_col6" class="data row1 col6" >0.0746</td>
#       <td id="T_591ea_row1_col7" class="data row1 col7" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_591ea_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_591ea_row2_col1" class="data row2 col1" >0.6538</td>
#       <td id="T_591ea_row2_col2" class="data row2 col2" >2.5169</td>
#       <td id="T_591ea_row2_col3" class="data row2 col3" >1.5742</td>
#       <td id="T_591ea_row2_col4" class="data row2 col4" >0.9966</td>
#       <td id="T_591ea_row2_col5" class="data row2 col5" >0.2266</td>
#       <td id="T_591ea_row2_col6" class="data row2 col6" >0.0916</td>
#       <td id="T_591ea_row2_col7" class="data row2 col7" >0.8500</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_591ea_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_591ea_row3_col1" class="data row3 col1" >0.5405</td>
#       <td id="T_591ea_row3_col2" class="data row3 col2" >4.1696</td>
#       <td id="T_591ea_row3_col3" class="data row3 col3" >2.0027</td>
#       <td id="T_591ea_row3_col4" class="data row3 col4" >0.9944</td>
#       <td id="T_591ea_row3_col5" class="data row3 col5" >0.1645</td>
#       <td id="T_591ea_row3_col6" class="data row3 col6" >0.0836</td>
#       <td id="T_591ea_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_591ea_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_591ea_row4_col1" class="data row4 col1" >1.3578</td>
#       <td id="T_591ea_row4_col2" class="data row4 col2" >6.2672</td>
#       <td id="T_591ea_row4_col3" class="data row4 col3" >2.4984</td>
#       <td id="T_591ea_row4_col4" class="data row4 col4" >0.9916</td>
#       <td id="T_591ea_row4_col5" class="data row4 col5" >0.4339</td>
#       <td id="T_591ea_row4_col6" class="data row4 col6" >0.1856</td>
#       <td id="T_591ea_row4_col7" class="data row4 col7" >0.1630</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_591ea_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_591ea_row5_col1" class="data row5 col1" >5.7260</td>
#       <td id="T_591ea_row5_col2" class="data row5 col2" >47.3015</td>
#       <td id="T_591ea_row5_col3" class="data row5 col3" >6.8591</td>
#       <td id="T_591ea_row5_col4" class="data row5 col4" >0.9359</td>
#       <td id="T_591ea_row5_col5" class="data row5 col5" >1.4962</td>
#       <td id="T_591ea_row5_col6" class="data row5 col6" >0.4739</td>
#       <td id="T_591ea_row5_col7" class="data row5 col7" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_591ea_level0_

# %%
best
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## Model Interpretation
#
# You can get more details about why the best model is the best. PyCaret provides a function called interpret_model. It will produce a figure showing the influence of each input variable on the results. It is actually the same result of SHAP library and PyCaret integrates it.

# %%
interpret_model(best)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
