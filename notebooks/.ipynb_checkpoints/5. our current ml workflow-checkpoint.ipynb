# %% [markdown]
# ## Current SWE Forecasting Workflow
#
# Please check the workflow in Geoweaver here: http://ec2-54-213-131-7.us-west-2.compute.amazonaws.com:8070/Geoweaver/web/geoweaver Click on `snowcast_wormhole` and should display the following graph:
#
# ![image.png](attachment:b15e4753-cd17-4688-ade9-333d96c57ed3.png)
#
# All the source code could be found in two places:
#
# - SnowCast repository (updated frequently and synced with prod): https://github.com/geo-smart/SnowCast
# - hackweek project folder (just a snapshot): https://github.com/geo-smart/swe_forecasting_prod/tree/main/scripts
