# %% [markdown]
# ## Map Generation
#
# The current map is generated by matplotlib. It is not bad, but we can do it better! With better style, basemap, and maybe interactive map mode of any existing libraries!
